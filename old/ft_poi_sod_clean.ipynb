# %% [markdown]
# Following section reads monthly foot traffic data based on the locations saved in poi_sod.csv.gz, and saves read data into filtered_ft_data.csv

# %%
import requests
import pandas as pd
import sys
from io import BytesIO
import gzip
import io
import os
from global_variables import *

# %%
poi_sod_file = "C:/Users/dratnadiwakara2/Documents/OneDrive - Louisiana State University/Raw Data/Dewey/poi_sod.csv.gz" 
poi_sod = pd.read_csv(poi_sod_file, compression='gzip')

# %%
results = requests.get(url=MONTHLY_FT_PATTERNS_PRODUCT_API_PATH,
                       params={
                               'partition_key_after': '2019-11-01',   # optionally set date value here
                               'partition_key_before': '2022-12-01'}, # optionally set date value here
                       headers={'X-API-KEY': API_KEY,
                                'accept': 'application/json'
                               })
response_json = results.json()

# %% [markdown]
# https://community.deweydata.io/t/bulk-downloading-data-using-v3-api-using-python/26533
# https://github.com/amplifydata/amplifydata-public/blob/main/README.md

# %%
ft_data_path = 'C:/Users/dratnadiwakara2/Downloads/temp_dewey/filtered_ft_data.csv'
page = 1
download_count = 0
while True:
    print(page)
    results = requests.get(url=MONTHLY_FT_PATTERNS_PRODUCT_API_PATH,
                       params={'page': page,
                               'partition_key_after': '2019-11-01',   # optionally set date value here
                               'partition_key_before': '2021-12-01'}, # optionally set date value here
                       headers={'X-API-KEY': API_KEY,
                                'accept': 'application/json'
                               })
    response_json = results.json()

    for link_data in response_json['download_links']:
        print(f"Downloading file {link_data['file_name']}...")
    
        data = requests.get(link_data['link'])
        gzip_stream = io.BytesIO(data.content)
    
        df = pd.read_csv(gzip_stream, compression='gzip', low_memory=False)
        filtered_df = df[df['PLACEKEY'].isin(poi_sod['PLACEKEY'])]
    
        if os.path.isfile(ft_data_path):
            header_option = False  
        else:
            header_option = True  
    
        filtered_df.to_csv(ft_data_path, mode='a', header=header_option, index=False)
        
        download_count += 1
        
    total_pages = response_json['total_pages']
    if page >= total_pages:
        break
    page += 1
# Out:
# 1
# Downloading file Monthly_Patterns_Foot_Traffic-0-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-1-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-2-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-3-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-4-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-5-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-6-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-7-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-8-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-9-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-10-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-11-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-12-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-13-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-14-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-15-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-16-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-17-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-18-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-19-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-20-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-21-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-22-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-23-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-24-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-25-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-26-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-27-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-28-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-29-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-30-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-31-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-32-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-33-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-34-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-35-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-36-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-37-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-38-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-39-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-40-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-41-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-42-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-43-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-44-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-45-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-46-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-47-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-48-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-49-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-50-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-51-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-52-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-53-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-54-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-55-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-56-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-57-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-58-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-59-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-60-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-61-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-62-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-63-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-64-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-65-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-66-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-67-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-68-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-69-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-70-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-71-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-72-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-73-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-74-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-75-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-76-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-77-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-78-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-79-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-80-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-81-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-82-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-83-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-84-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-85-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-86-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-87-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-88-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-89-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-90-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-91-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-92-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-93-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-94-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-95-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-96-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-97-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-98-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-99-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-100-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-101-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-102-DATE_RANGE_START-2019-11-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-103-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-104-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-105-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-106-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-107-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-108-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-109-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-110-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-111-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-112-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-113-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-114-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-115-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-116-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-117-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-118-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-119-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-120-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-121-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-122-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-123-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-124-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-125-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-126-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-127-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-128-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-129-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-130-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-131-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-132-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-133-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-134-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-135-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-136-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-137-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-138-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-139-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-140-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-141-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-142-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-143-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-144-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-145-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-146-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-147-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-148-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-149-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-150-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-151-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-152-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-153-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-154-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-155-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-156-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-157-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-158-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-159-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-160-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-161-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-162-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-163-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-164-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-165-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-166-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-167-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-168-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-169-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-170-DATE_RANGE_START-2019-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-171-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-172-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-173-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-174-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-175-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-176-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-177-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-178-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-179-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-180-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-181-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-182-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-183-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-184-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-185-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-186-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-187-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-188-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-189-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-190-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-191-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-192-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-193-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-194-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-195-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-196-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-197-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-198-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-199-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-200-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-201-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-202-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-203-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-204-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-205-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-206-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-207-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-208-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-209-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-210-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-211-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-212-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-213-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-214-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-215-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-216-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-217-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-218-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-219-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-220-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-221-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-222-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-223-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-224-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-225-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-226-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-227-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-228-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-229-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-230-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-231-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-232-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-233-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-234-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-235-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-236-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-237-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-238-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-239-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-240-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-241-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-242-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-243-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-244-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-245-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-246-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-247-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-248-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-249-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-250-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-251-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-252-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-253-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-254-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-255-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-256-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-257-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-258-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-259-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-260-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-261-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-262-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-263-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-264-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-265-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-266-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-267-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-268-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-269-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-270-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-271-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-272-DATE_RANGE_START-2020-01-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-273-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-274-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-275-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-276-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-277-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-278-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-279-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-280-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-281-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-282-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-283-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-284-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-285-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-286-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-287-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-288-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-289-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-290-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-291-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-292-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-293-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-294-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-295-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-296-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-297-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-298-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-299-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-300-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-301-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-302-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-303-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-304-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-305-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-306-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-307-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-308-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-309-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-310-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-311-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-312-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-313-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-314-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-315-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-316-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-317-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-318-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-319-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-320-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-321-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-322-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-323-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-324-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-325-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-326-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-327-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-328-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-329-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-330-DATE_RANGE_START-2020-02-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-331-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-332-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-333-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-334-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-335-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-336-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-337-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-338-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-339-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-340-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-341-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-342-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-343-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-344-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-345-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-346-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-347-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-348-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-349-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-350-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-351-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-352-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-353-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-354-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-355-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-356-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-357-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-358-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-359-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-360-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-361-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-362-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-363-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-364-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-365-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-366-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-367-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-368-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-369-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-370-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-371-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-372-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-373-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-374-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-375-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-376-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-377-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-378-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-379-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-380-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-381-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-382-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-383-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-384-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-385-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-386-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-387-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-388-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-389-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-390-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-391-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-392-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-393-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-394-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-395-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-396-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-397-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-398-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-399-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-400-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-401-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-402-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-403-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-404-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-405-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-406-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-407-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-408-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-409-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-410-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-411-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-412-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-413-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-414-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-415-DATE_RANGE_START-2020-03-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-416-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-417-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-418-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-419-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-420-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-421-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-422-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-423-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-424-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-425-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-426-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-427-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-428-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-429-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-430-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-431-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-432-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-433-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-434-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-435-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-436-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-437-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-438-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-439-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-440-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-441-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-442-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-443-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-444-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-445-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-446-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-447-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-448-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-449-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-450-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-451-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-452-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-453-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-454-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-455-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-456-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-457-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-458-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-459-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-460-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-461-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-462-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-463-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-464-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-465-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-466-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-467-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-468-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-469-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-470-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-471-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-472-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-473-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-474-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-475-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-476-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-477-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-478-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-479-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-480-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-481-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-482-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-483-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-484-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-485-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-486-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-487-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-488-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-489-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-490-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-491-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-492-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-493-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-494-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-495-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-496-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-497-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-498-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-499-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-500-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-501-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-502-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-503-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-504-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-505-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-506-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-507-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-508-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-509-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-510-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-511-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-512-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-513-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-514-DATE_RANGE_START-2020-04-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-515-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-516-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-517-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-518-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-519-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-520-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-521-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-522-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-523-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-524-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-525-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-526-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-527-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-528-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-529-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-530-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-531-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-532-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-533-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-534-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-535-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-536-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-537-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-538-DATE_RANGE_START-2020-05-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-539-DATE_RANGE_START-2020-05-01.csv.gz...
# ...
# Downloading file Monthly_Patterns_Foot_Traffic-867-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-868-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-869-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-870-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-871-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-872-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-873-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-874-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-875-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-876-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-877-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-878-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-879-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-880-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-881-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-882-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-883-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-884-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-885-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-886-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-887-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-888-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-889-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-890-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-891-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-892-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-893-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-894-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-895-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-896-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-897-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-898-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-899-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-900-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-901-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-902-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-903-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-904-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-905-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-906-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-907-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-908-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-909-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-910-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-911-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-912-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-913-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-914-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-915-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-916-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-917-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-918-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-919-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-920-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-921-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-922-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-923-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-924-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-925-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-926-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-927-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-928-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-929-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-930-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-931-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-932-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-933-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-934-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-935-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-936-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-937-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-938-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-939-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-940-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-941-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-942-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-943-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-944-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-945-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-946-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-947-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-948-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-949-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-950-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-951-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-952-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-953-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-954-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-955-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-956-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-957-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-958-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-959-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-960-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-961-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-962-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-963-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-964-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-965-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-966-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-967-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-968-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-969-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-970-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-971-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-972-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-973-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-974-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-975-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-976-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-977-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-978-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-979-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-980-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-981-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-982-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-983-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-984-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-985-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-986-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-987-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-988-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-989-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-990-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-991-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-992-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-993-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-994-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-995-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-996-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-997-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-998-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-999-DATE_RANGE_START-2021-12-01.csv.gz...
# 3
# Downloading file Monthly_Patterns_Foot_Traffic-0-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-1-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-2-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-3-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-4-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-5-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-6-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-7-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-8-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-9-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-10-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-11-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-12-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-13-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-14-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-15-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-16-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-17-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-18-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-19-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-20-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-21-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-22-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-23-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-24-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-25-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-26-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-27-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-28-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-29-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-30-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-31-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-32-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-33-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-34-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-35-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-36-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-37-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-38-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-39-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-40-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-41-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-42-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-43-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-44-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-45-DATE_RANGE_START-2021-12-01.csv.gz...
# Downloading file Monthly_Patterns_Foot_Traffic-46-DATE_RANGE_START-2021-12-01.csv.gz...

# %%
ft_data = pd.read_csv(ft_data_path)
ft_data = ft_data.dropna(subset=['VISITOR_HOME_CBGS'])
ft_data = ft_data.reset_index()
print(ft_data['PLACEKEY'].nunique())
# Out:
# 119641

# %%
output_file_path = 'C:/Users/dratnadiwakara2/Downloads/temp_dewey/filtered_ft_data.csv'+'.gz'
with gzip.open(output_file_path, 'wt', encoding='utf-8') as gzipped_file:
    ft_data.to_csv(gzipped_file, index=False)

# %% [markdown]
# Following section reads cleaned poi and sod data and matches the two datasets

# %%
import time
from tqdm import tqdm
import requests
import pandas as pd
import os
from io import BytesIO
import gzip
from global_variables import *

# %%
# next section has the code to create these files
poi_file = "C:/Users/dratnadiwakara2/Documents/OneDrive - Louisiana State University/Raw Data/Dewey/poi_with_usps_address.csv.gz" 
sod_file = "C:/Users/dratnadiwakara2/Documents/OneDrive - Louisiana State University/Raw Data/Dewey/sod_data_branches_with_usps_address.csv.gz"

# %%
poi = pd.read_csv(poi_file, compression='gzip')
sod = pd.read_csv(sod_file, compression='gzip')

# %%
poi = poi.drop_duplicates()

# %%
sod = sod.drop_duplicates(subset='usps_address', keep='first')

# %%
poi_sod = poi.merge(sod[['usps_address', 'NAMEBR', 'NAMEFULL', 'SIMS_LATITUDE', 'SIMS_LONGITUDE', 'UNINUMBR', 'CERT']], on='usps_address', how='inner')

# %%
output_file_path = "C:/Users/dratnadiwakara2/Documents/OneDrive - Louisiana State University/Raw Data/Dewey/poi_sod.csv.gz" 
with gzip.open(output_file_path, 'wt', encoding='utf-8') as gzipped_file:
    poi_sod.to_csv(gzipped_file, index=False)

# %% [markdown]
# The section below cleans poi and sod data and convert the address in both the files to USPS format

# %%
import time
from tqdm import tqdm
import requests
import pandas as pd
import os
from io import BytesIO
import gzip
from global_variables import *
import urllib.request
import xml.etree.ElementTree as ET

# %%
# this function uses USPS api to get the verified USPS address
def get_usps_address(street,city,state,zip):
    xml_string = (
        '<?xml version="1.0"?>\n'
        '<AddressValidateRequest USERID="33LOUIS8M0561">\n'
        '    <Revision>1</Revision>\n'
        '    <Address ID="0">\n'
        f'        <Address1>{street}</Address1>\n'
        '        <Address2></Address2>\n'
        f'        <City>{city}</City>\n'
        f'        <State>{state}</State>\n'
        f'        <Zip5>{zip}</Zip5>\n'
        '        <Zip4/>\n'
        '    </Address>\n'
        '</AddressValidateRequest>'
    )
    xml_string = xml_string.replace('\n','').replace('\t','')
    xml_string = urllib.parse.quote_plus(xml_string)
    xml_string = "http://production.shippingapis.com/ShippingAPI.dll?API=Verify&XML=" + xml_string
    response = urllib.request.urlopen(xml_string)
    if response.getcode() == 200:
        contents = response.read()
        return contents
    else:
        return 'error'

# %%
results = requests.get(url=POI_Data_PRODUCT_API_PATH,
                       params={}, # optionally set date value here
                       headers={'X-API-KEY': API_KEY,
                                'accept': 'application/json'
                               })
response_json = results.json()

# %% [markdown]
# ## Read Data
#
# The following script reads data, filters US POI, and select important columns, and saves output as a csv file.

# %%
poi_csv_path = 'C:/Users/dratnadiwakara2/Documents/OneDrive - Louisiana State University/Raw Data/Dewey/poi_us_banks.csv'

# %%
# for link_data in response_json['download_links']:
# 
#     print(f"Downloading file {link_data['file_name']}...")
# 
#     df = pd.read_csv(BytesIO(requests.get(link_data['link']).content), compression="gzip")
#     df = df[df['ISO_COUNTRY_CODE'] == 'US'][['CATEGORY_TAGS', 'CITY', 'LATITUDE','LONGITUDE','NAICS_CODE','PLACEKEY','POSTAL_CODE','REGION','STREET_ADDRESS','SUB_CATEGORY','TOP_CATEGORY','LOCATION_NAME']]
#     df = df[(df['TOP_CATEGORY'] == 'Depository Credit Intermediation') | (df['NAICS_CODE'].astype(str).str[:3] == '522')]
#     df = df.reset_index()
# 
#     if os.path.isfile(poi_csv_path):
#         header_option = False  
#     else:
#         header_option = True  
# 
#     df.to_csv(poi_csv_path, mode='a', header=header_option, index=False)
# 
# df = pd.read_csv(poi_csv_path)    
# 
# with gzip.open(poi_csv_path+".gz", 'wt', encoding='utf-8') as gzipped_file:
#     df.to_csv(gzipped_file, index=False)

# %%
with gzip.open(poi_csv_path+".gz", 'rt', encoding='utf-8') as gzipped_file:
    poi = pd.read_csv(gzipped_file)

poi = poi.reset_index()
poi['POSTAL_CODE'] = poi['POSTAL_CODE'].astype(int)
poi['full_address_poi'] = poi['STREET_ADDRESS'].str.lower()+", "+poi['CITY'].str.lower()+", "+poi['POSTAL_CODE'].astype(str)+" "+ poi['REGION'].str.lower()

# %%
poi['usps_contents'] = ''
poi  = poi.reset_index(drop=True)

output_file_path = "C:/Users/dratnadiwakara2/Documents/OneDrive - Louisiana State University/Raw Data/Dewey/poi_full_address.csv"

# %%
with tqdm(total=(len(poi)-28871) ) as pbar:
    with open(output_file_path, "a") as output_file:
        for index in range(28871, len(poi)):
            row = poi.iloc[index]
            num_rows = len(poi)
            break_interval = 400
            
            if (index + 1) % break_interval == 0 and index != (num_rows - 1):
                time.sleep(1)  # Sleep for one second
                
            try:
                op = get_usps_address(row['STREET_ADDRESS'],row['CITY'],row['REGION'],row['POSTAL_CODE'])
                poi.loc[index,'usps_contents'] = op
                output_file.write(f"{row['full_address_poi']}|{index}|{op}\n")
            except Exception as e:
                print(f"An exception occurred: {e}")
                break
            pbar.update(1)
# Out:
# 100%|██████████| 532164/532164 [28:10:35<00:00,  5.25it/s]

# %%
poi['usps_address'] = ''
with tqdm(total=len(poi) ) as pbar:
    for index, row in poi.iterrows():
        root = ET.fromstring(poi.loc[index,'usps_contents'])
        if len(root.findall("Address"))==1:
            try:
                add_xml  =  root.findall("Address")[0]
                add_text = add_xml.find("Address2").text+" "+add_xml.find("City").text+" "+add_xml.find("State").text+" "+add_xml.find("Zip5").text
                if add_xml.find("Address1") is not None:
                    add_text = add_text+" "+add_xml.find("Address1").text
                poi.loc[index,'usps_address'] = add_text
            except:
                pass
        pbar.update(1)
# Out:
# 100%|██████████| 561035/561035 [02:25<00:00, 3851.05it/s]

# %%
output_file_path = "C:/Users/dratnadiwakara2/Documents/OneDrive - Louisiana State University/Raw Data/Dewey/poi_with_usps_address.csv.gz" 
with gzip.open(output_file_path, 'wt', encoding='utf-8') as gzipped_file:
    poi.to_csv(gzipped_file, index=False)

# %% [markdown]
# ## SOD Data

# %%
sod_files_path = 'C:/Users/dratnadiwakara2/Documents/OneDrive - Louisiana State University/Raw Data/SOD/data/'

sod_data = ['ALL_2019.csv','ALL_2020.csv','ALL_2021.csv','ALL_2022.csv','ALL_2023.csv']

sod_data_files = [sod_files_path + s for s in sod_data]

selected_columns = ['YEAR','CERT','BRNUM','UNINUMBR','NAMEFULL','ADDRESBR','CITYBR',	'CNTYNAMB','STALPBR','ZIPBR','NAMEBR','SIMS_LATITUDE','SIMS_LONGITUDE']  

combined_df = pd.DataFrame(columns=selected_columns)

for csv_file in sod_data_files:
    df = pd.read_csv(csv_file, encoding='latin-1')
    selected_df = df[selected_columns]
    combined_df = pd.concat([combined_df, selected_df], ignore_index=True)

combined_df = combined_df.reset_index()
# Out:
# C:\Users\dratnadiwakara2\AppData\Local\Temp\ipykernel_15720\4200346606.py:14: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_df = pd.concat([combined_df, selected_df], ignore_index=True)

# %%
sod_data_branches = combined_df.drop_duplicates(subset=['UNINUMBR'])
sod_data_branches = sod_data_branches.reset_index()

# %%
sod_data_branches['full_address_sod'] = sod_data_branches['ADDRESBR'].str.lower()+", "+sod_data_branches['CITYBR'].str.lower()+", "+sod_data_branches['ZIPBR'].astype(str)+" "+sod_data_branches['STALPBR'].str.lower()

# %%
sod_data_branches['full_address_sod'][0]
# Out:
# '1 lincoln st. fl 1, boston, 2111 ma'

# %%
sod_data_branches['usps_contents'] = ''
sod_data_branches  = sod_data_branches.reset_index(drop=True)

output_file_path = "C:/Users/dratnadiwakara2/Documents/OneDrive - Louisiana State University/Raw Data/Dewey/sod_full_address.csv"  

with tqdm(total=len(sod_data_branches) ) as pbar:
    with open(output_file_path, "a") as output_file:
        for index, row in sod_data_branches.iterrows():
            num_rows = len(sod_data_branches)
            break_interval = 400
            
            if (index + 1) % break_interval == 0 and index != (num_rows - 1):
                time.sleep(1)  # Sleep for one second
                
            try:
                op = get_usps_address(row['ADDRESBR'],row['CITYBR'],row['STALPBR'],row['ZIPBR'])
                sod_data_branches.loc[index,'usps_contents'] = op
                output_file.write(f"{row['full_address_sod']}|{index}|{op}\n")
            except:
                print('error')
                break
            pbar.update(1)
# Out:
# 100%|██████████| 90924/90924 [4:57:49<00:00,  5.09it/s]

# %%
sod_data_branches['usps_address'] = ''
with tqdm(total=len(sod_data_branches) ) as pbar:
    for index, row in sod_data_branches.iterrows():
        root = ET.fromstring(sod_data_branches.loc[index,'usps_contents'])
        if len(root.findall("Address"))==1:
            try:
                add_xml  =  root.findall("Address")[0]
                add_text = add_xml.find("Address2").text+" "+add_xml.find("City").text+" "+add_xml.find("State").text+" "+add_xml.find("Zip5").text
                if add_xml.find("Address1") is not None:
                    add_text = add_text+" "+add_xml.find("Address1").text
                sod_data_branches.loc[index,'usps_address'] = add_text
            except:
                pass
        pbar.update(1)
# Out:
# 100%|██████████| 90924/90924 [00:20<00:00, 4428.05it/s]

# %%
output_file_path = "C:/Users/dratnadiwakara2/Documents/OneDrive - Louisiana State University/Raw Data/Dewey/sod_data_branches_with_usps_address.csv.gz" 
with gzip.open(output_file_path, 'wt', encoding='utf-8') as gzipped_file:
    sod_data_branches.to_csv(gzipped_file, index=False)

# %% [markdown]
# # Ignore below this
# ## Match by longitude and latitude

# %%
df1 = sod_data_branches[['full_address_sod', 'match_string_2']]
df2 = poi[['full_address_poi', 'match_string_2']]

# Merge df1 and df2 on 'match_string_2' to create matched_data_2
matched_data_2 = pd.merge(df1, df2, on='match_string_2', how='inner')

# %% [markdown]
# ## Fuzzy Match

# %%
from fuzzywuzzy import fuzz
from tqdm import tqdm
from fuzzywuzzy import process
# Out:
# C:\Users\dratnadiwakara2\Documents\OneDrive - Louisiana State University\Projects\Dewey\venv\Lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
def address_similarity(address1, address2):
    return fuzz.ratio(address1.lower(), address2.lower())

# %%
output_file_path = "C:/Users/dratnadiwakara2/Documents/OneDrive - Louisiana State University/Raw Data/Dewey/bank_branch_matches.csv"  

with tqdm(total=len(sod_data_branches) ) as pbar:
    with open(output_file_path, "a") as output_file:
        for index1, row1 in sod_data_branches.iterrows():
            mask = (poi['match_string'].str.lower() == row1['match_string'].lower())
            temp = poi[mask]
            for index2, row2 in temp.iterrows():
                try:
                        similarity_score = address_similarity(row1['full_address_sod'], row2['full_address_poi'])
                        if similarity_score >= 50: 
                            output_file.write(f"{row1['full_address_sod']}|{row2['full_address_poi']}|{similarity_score}\n")
                except:
                    pass
            pbar.update(1)
# Out:
# 100%|██████████| 90924/90924 [16:49:50<00:00,  1.50it/s]

# %%
matched_data = pd.read_csv(output_file_path,sep="|",header=None)
matched_data.rename(columns={0:'full_address_sod',1:'full_address_poi',2:'similarity_score'}, inplace=True)
matched_data = matched_data.drop_duplicates()
matched_data = matched_data.sort_values(by='similarity_score', ascending=False)
matched_data = matched_data[(matched_data['similarity_score'] >= 90) & (matched_data['full_address_sod'].str[:2] == matched_data['full_address_poi'].str[:2])]
matched_data = matched_data.drop_duplicates(subset='full_address_sod')

# %%
poi_matched = poi[poi['full_address_poi'].isin(matched_data['full_address_poi'])]

# %%
poi_category_count = poi_matched.groupby('NAICS_CODE').size().reset_index(name='Frequency')
# TOP_CATEGORY: Depository Credit Intermediation

# %%
requestXML = """
<?xml version="1.0"?>
<AddressValidateRequest USERID="33LOUIS8M0561">
	<Revision>1</Revision>
	<Address ID="0">
		<Address1>2335 S State, ste 300</Address1>
		<Address2></Address2>
		<City>Provo</City>
		<State>UT</State>
		<Zip5>84604</Zip5>
		<Zip4/>
	</Address>
</AddressValidateRequest>
"""

# %%
docString = requestXML
docString = docString.replace('\n','').replace('\t','')
docString = urllib.parse.quote_plus(docString)

url = "http://production.shippingapis.com/ShippingAPI.dll?API=Verify&XML=" + docString
#print(url + "\n\n")

response = urllib.request.urlopen(url)
if response.getcode() != 200:
	print("Error making HTTP call:")
	print(response.info())
	exit()

contents = response.read()

root = ET.fromstring(contents)
for address in root.findall('Address'):
	print()
	print("Address1: " + address.find("Address1").text)
	print("Address2: " + address.find("Address2").text)
	print("City:	 " + address.find("City").text)
	print("State:	" + address.find("State").text)
	print("Zip5:	 " + address.find("Zip5").text)
# Out:
# Address1: STE 300
# Address2: 2335 S STATE ST
# City:	 PROVO
# State:	UT
# Zip5:	 84606

# %%
def create_xml_string(row):
    xml_string = (
        '<?xml version="1.0"?>\n'
        '<AddressValidateRequest USERID="33LOUIS8M0561">\n'
        '    <Revision>1</Revision>\n'
        '    <Address ID="0">\n'
        f'        <Address1>{row["address"]}</Address1>\n'
        '        <Address2></Address2>\n'
        f'        <City>{row["city"]}</City>\n'
        f'        <State>{row["state"]}</State>\n'
        f'        <Zip5>{row["zip"]}</Zip5>\n'
        '        <Zip4/>\n'
        '    </Address>\n'
        '</AddressValidateRequest>'
    )
    return xml_string

# Create a new column 'xml_string' using the function
df['xml_string'] = df.apply(create_xml_string, axis=1)
